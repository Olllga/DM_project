# %% [markdown]
# #**Imports**

# %%
from google.colab import drive
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

from torchvision.transforms.functional import to_pil_image
from torchvision import models, transforms

from fastai.callbacks import hook_outputs
from fastai.torch_core import requires_grad, children

# %%
# check if training using GPU is possible
torch.cuda.is_available()

# %% [markdown]
# #**Downloading dataset from Kaggle to Google Drive**

# %%
# mounting Google Drive with your credentials 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# folder, created in advance in the Google Drive and containing kaggle.json
#project_folder = "/content/gdrive/My Drive/Kaggle/NaturalPainters" # for original email
project_folder = "/content/gdrive/My Drive/NaturalPainters" 
os.environ['KAGGLE_CONFIG_DIR'] = project_folder

# %%
# dive into folder
#%cd /content/gdrive/MyDrive/Kaggle/NaturalPainters
# %cd /content/gdrive/MyDrive/NaturalPainters

# %%
# download dataset from the given Kaggle page to the current folder
# !kaggle datasets download -d reiinakano/mypaint_brushstrokes

# %%
# data is currently dowloaded as a zip-folder, we need to unzip it
# !unzip \*.zip  && rm *.zip

# %% [markdown]
# #**Show Dataset**

# %%
# data is stored in the 'episodes_i.npz' format, where i is in {0,...,77}
# this routine loads desired 'episodes_i.npz' for a particular i
# data will be loaded in the dictionary with two fields: 'strokes' and 'actions'
def load_data(npz):

    data = np.load('strokes-dataset/' + npz)
    return data['strokes'], data['actions']

# %%
# example 'episodes_i.npz' for i = 0, takes 196.3MB
current_npz = 'episodes_0.npz'

strokes, actions = load_data(current_npz)
print(f"Strokes are {strokes.shape[0]} images with img_width = {strokes.shape[1]}, img_height = {strokes.shape[2]} and n_channels = {strokes.shape[3]}")
print(f"Actions are {actions.shape[0]} arrays of dimension {actions.shape[1]}")
# Out:
# Strokes are 100000 images with img_width = 64, img_height = 64 and n_channels = 3
# Actions are 100000 arrays of dimension 12

# %%
# printing routine for images in 'strokes' and corresponding numerical arrays in 'actions'
def print_data(strokes, 
               figsize = [12, 5], nrows = 2, ncols = 6,
               savepath = None):

    fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize = figsize)

    for i, ax in enumerate(axes.flat):
        img = strokes[i]
        ax.imshow(img)
        ax.set_title("Stroke " + str(i + 1))

    plt.tight_layout(True)

    if(savepath):
        plt.savefig(savepath, dpi = 200)
        print(f"Images were saved in {savepath}.")

    print(f"Example of {nrows*ncols} strokes:\n")
    plt.show()

# %%
# print first n_elem data samples
n_elem = 12
print_data(strokes[:n_elem], savepath = project_folder + "/example_imgs")
print(f"Example of {n_elem} actions:\n")
print(actions[:n_elem])
# Out:
# Images were saved in /content/gdrive/My Drive/NaturalPainters/example_imgs.
# Example of 12 strokes:
# Example of 12 actions:
#
# [[0.70163  0.30781  0.905674 0.382132 ... 0.327325 0.801232 0.132051 0.791512]
#  [0.286395 0.565084 0.509936 0.343041 ... 0.463403 0.827277 0.10558  0.170216]
#  [0.882056 0.469463 0.533015 0.174413 ... 0.358329 0.693955 0.602135 0.246814]
#  [0.361594 0.893709 0.828945 0.408551 ... 0.560948 0.591296 0.712416 0.049876]
#  ...
#  [0.210662 0.909512 0.665188 0.632399 ... 0.783824 0.147759 0.905845 0.770463]
#  [0.792833 0.392336 0.247886 0.700524 ... 0.280456 0.02041  0.702323 0.898893]
#  [0.918944 0.082216 0.216768 0.610269 ... 0.695325 0.237305 0.939507 0.850217]
#  [0.283974 0.291432 0.758155 0.204911 ... 0.078169 0.244963 0.080239 0.511231]]

# %% [markdown]
# # **Generator**

# %%
class Generator(nn.Module):

    def __init__(self, 
                 in_features: int,
                 img_height: int,
                 img_width: int,
                 num_features: int,
                 img_channels: int):
      super(Generator, self).__init__()

      self.out_features = img_height * img_width

      self.lin = nn.Linear(in_features, self.out_features)

      self.conv1 = nn.ConvTranspose2d(self.out_features, num_features, 
                                      kernel_size = (4, 4), stride = (1, 1), bias = False)
      self.norm1 = nn.BatchNorm2d(num_features)

      self.conv2 = nn.ConvTranspose2d(num_features, num_features//2, 
                                      kernel_size = (4, 4), stride = (2, 2), padding = (1, 1), bias = False)
      num_features //= 2
      self.norm2 = nn.BatchNorm2d(num_features)

      self.conv3 = nn.ConvTranspose2d(num_features, num_features//2, 
                                      kernel_size = (4, 4), stride = (2, 2), padding = (1, 1), bias = False)
      num_features //= 2
      self.norm3 = nn.BatchNorm2d(num_features)

      self.conv4 = nn.ConvTranspose2d(num_features, num_features//2, 
                                      kernel_size = (4, 4), stride = (2, 2), padding = (1, 1), bias = False)
      num_features //= 2
      self.norm4 = nn.BatchNorm2d(num_features)

      self.conv5 = nn.ConvTranspose2d(num_features, num_features, 
                                      kernel_size = (3, 3), stride = (1, 1), padding = (1, 1), bias = False)
      self.norm5 = nn.BatchNorm2d(num_features)

      self.conv6 = nn.ConvTranspose2d(num_features, img_channels, 
                                      kernel_size = (4, 4), stride = (2, 2), padding = (1, 1), bias = False)



    def forward(self, x):
      x = self.lin(x)
      x = F.relu(self.conv1(x.view(x.size(0), x.size(1), 1, 1)), inplace = True)
      x = self.norm1(x)
      x = F.relu(self.conv2(x), inplace = True)
      x = self.norm2(x)
      x = F.relu(self.conv3(x), inplace = True)
      x = self.norm3(x)
      x = F.relu(self.conv4(x), inplace = True)
      x = self.norm4(x)
      x = F.relu(self.conv5(x), inplace = True)
      x = self.norm5(x)

      return torch.tanh(self.conv6(x))

# %%
# to check created model
# generator = Generator(12, 64, 64, 512, 3)
# generator

# %%
# just to check on the output of the dataloader
# for (_, act) in dataloader:
#   print(act)
#   break
# generator(act)

# %%
# to see all vgg19_bn layers and indices of chosen for feature extraction ones
# extractor = models.vgg19_bn(True).features.cuda().eval()
# requires_grad(extractor, False)
# blocks = [i-1 for i,o in enumerate(children(extractor)) if isinstance(o, nn.MaxPool2d)]
# print(blocks, blocks[2:])

# %%
class FeatureExtractor(nn.Module):

    def __init__(self, 
                 layers_weights,
                 device):
      super(FeatureExtractor, self).__init__()
      
      self.layers_weights = layers_weights
      self.device = device
      self.feature_extractor, self.layers_indices = self.extractor()
      self.outputs = hook_outputs([self.feature_extractor[i] for i in self.layers_indices], detach = False)

    def extractor(self):
        print("Download VGG19 (batch normalized) as pre-trained.")
        if device == 'cuda':
            extractor = models.vgg19_bn(True).features.cuda().eval()
        else:
            extractor = models.vgg19_bn(True).features.eval()
        requires_grad(extractor, False)
        return extractor, [i - 1 for i, layer in enumerate(children(extractor)) if isinstance(layer, nn.MaxPool2d)][2:]

    def gram_matrix(self, input):

        (a, b, c, d) = input.size()
        features = input.view(a, b, c * d)
        G = features @ features.transpose(1, 2)
        return G.div(b * c * d)

    def forward(self, gen_stroke, true_stroke):

        self.feature_extractor(gen_stroke)
        gen_stroke_features = [out for out in self.outputs.stored]
        
        self.feature_extractor(true_stroke)
        true_stroke_features = [out.clone() for out in self.outputs.stored]

        self.loss = []
        
        feature_loss = [F.l1_loss(gen_layer, true_layer) * weight
                             for gen_layer, true_layer, weight 
                        in zip(gen_stroke_features, true_stroke_features, self.layers_weights)]
        

        style_loss = [F.l1_loss(self.gram_matrix(gen_layer), self.gram_matrix(true_layer)) * weight**2 * 5000
                             for gen_layer, true_layer, weight 
                      in zip(gen_stroke_features, true_stroke_features, self.layers_weights)]
    
        pixel_loss = [F.l1_loss(gen_stroke, true_stroke)]

        self.loss += feature_loss + style_loss + pixel_loss
                
        return sum(self.loss)

    def __del__(self):
        
        self.outputs.remove()

# %%
strokes_tfms = transforms.Compose([transforms.Lambda(lambda x: x.float()),
                                   transforms.Lambda(lambda x: x.div_(255))
                                  ])

# %%
torch.manual_seed(4)
class Trainer():

    def __init__(self, 
                 transforms,
                 generator: nn.Module,
                 feature_extractor: nn.Module,
                 optimizer: torch.optim,
                 epochs: int = 5,
                 gpu: bool = False):
      super(Trainer, self).__init__()

      self.transforms = transforms
      self.generator = generator
      self.feature_extractor = feature_extractor
      self.optimizer = optimizer
      self.epochs = epochs
      self.gpu = gpu

    def train(self,
              dataloader,
              print_interval: int = 50):

        for epoch in range(self.epochs):

            self.generator.train()
            epoch_loss = []

            for i, (stroke, action) in enumerate(dataloader):

                stroke = torch.stack([self.transforms(s) for s in stroke])

                if self.gpu:
                  action = action.cuda()
                  stroke = stroke.cuda()

                self.optimizer.zero_grad()

                gen_stroke = self.generator(action)
                cur_loss = self.feature_extractor(gen_stroke, stroke)
                cur_loss.backward()

                self.optimizer.step()

                epoch_loss.append(cur_loss.data.item())
                
                if (i % print_interval) == 0:
                    print('Epoch {}/{} | Sample {}/{} => Loss: {:.3f}'.format((epoch + 1), self.epochs,
                                                                          (i + 1), len(dataloader),
                                                                          torch.mean(torch.FloatTensor(epoch_loss))))
                            
                    s = stroke[0].clone().cpu()
                    print('true stroke')
                    display(to_pil_image(s))
                    
                    g = gen_stroke[0].clone().cpu()
                    print('generated stroke')
                    display(to_pil_image(g))

                    print('-'*50)


            print('End of epoch {}'.format(epoch + 1))

        torch.save(self.generator.state_dict(), project_folder + '_generator_5152w_10e_1d.pth')

# %%
torch.manual_seed(4)
class Hparams():
    in_features = 12 #constant
    num_features = 512 #@param {type:"slider", min:8, max:1024, step:8}
    img_height = 64 #@param {type:"slider", min:8, max:1024, step:8}
    img_width = 64 #@param {type:"slider", min:8, max:1024, step:8}
    img_channels = 3 #@param {type:"slider", min:1, max:3, step:2}
    layers_weights = [5, 15, 2] #@param
    batch_size = 256 #@param {type: "slider", min:8, max:512, step:8}
    lr = 0.001 #@param {type:"number"}
    betas = (0.5, 0.9) #@param
    epochs = 15 #@param {type:"slider", min:1, max:1000, step:1}
    print_interval = 50 #@param {type:"slider", min:1, max:100, step:10}
hparams = Hparams()

current_npz = 'episodes_1.npz'

strokes, actions = load_data(current_npz)

strokes = torch.stack([torch.from_numpy(stroke).permute(2, 0, 1) for stroke in strokes])
actions = torch.stack([torch.from_numpy(action).float() for action in actions])

dataset = TensorDataset(strokes, actions)

dataloader = DataLoader(dataset, 
                        batch_size = hparams.batch_size, 
                        shuffle = False)

generator = Generator(hparams.in_features,
                      hparams.img_height,
                      hparams.img_width,
                      hparams.num_features,
                      hparams.img_channels)

feature_extractor = FeatureExtractor(hparams.layers_weights, device)

gpu = torch.cuda.is_available()
if gpu:
    print("Training is performed using GPU.\n")
    device = 'cuda'
else:
    print("Training is performed using CPU.\n")
    device = 'cpu'

generator.to(device)

optimizer = optim.Adam(generator.parameters(), 
                       lr = hparams.lr, 
                       betas = hparams.betas)

trainer = Trainer(strokes_tfms,
                  generator,
                  feature_extractor,
                  optimizer,
                  epochs = hparams.epochs,
                  gpu = gpu)

trainer.train(dataloader, 
              print_interval = hparams.print_interval)
# Out:
# Download VGG19 (batch normalized) as pre-trained.
# Training is performed using GPU.
#
# Epoch 1/10 | Sample 1/391 => Loss: 10.874
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41910D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4191610>
# --------------------------------------------------
# Epoch 1/10 | Sample 51/391 => Loss: 7.869
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A70571D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F08B9F94090>
# --------------------------------------------------
# Epoch 1/10 | Sample 101/391 => Loss: 7.207
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E388D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E38550>
# --------------------------------------------------
# Epoch 1/10 | Sample 151/391 => Loss: 6.783
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153510>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153750>
# --------------------------------------------------
# Epoch 1/10 | Sample 201/391 => Loss: 6.459
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190EE50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190EA10>
# --------------------------------------------------
# Epoch 1/10 | Sample 251/391 => Loss: 6.204
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20850>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A209D0>
# --------------------------------------------------
# Epoch 1/10 | Sample 301/391 => Loss: 5.990
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7057110>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F08B9F94090>
# --------------------------------------------------
# Epoch 1/10 | Sample 351/391 => Loss: 5.810
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7055D10>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E71090>
# --------------------------------------------------
# End of epoch 1
# Epoch 2/10 | Sample 1/391 => Loss: 4.559
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A202D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20BD0>
# --------------------------------------------------
# Epoch 2/10 | Sample 51/391 => Loss: 4.455
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A209D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20650>
# --------------------------------------------------
# Epoch 2/10 | Sample 101/391 => Loss: 4.413
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E71290>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E71710>
# --------------------------------------------------
# Epoch 2/10 | Sample 151/391 => Loss: 4.347
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A8133210>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9190>
# --------------------------------------------------
# Epoch 2/10 | Sample 201/391 => Loss: 4.294
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9710>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9ED0>
# --------------------------------------------------
# Epoch 2/10 | Sample 251/391 => Loss: 4.240
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7057110>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7542090>
# --------------------------------------------------
# Epoch 2/10 | Sample 301/391 => Loss: 4.183
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A70571D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3A10>
# --------------------------------------------------
# Epoch 2/10 | Sample 351/391 => Loss: 4.130
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3350>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E37D0>
# --------------------------------------------------
# End of epoch 2
# Epoch 3/10 | Sample 1/391 => Loss: 3.667
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7EAE4D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FE610>
# --------------------------------------------------
# Epoch 3/10 | Sample 51/391 => Loss: 3.613
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FEC10>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FE450>
# --------------------------------------------------
# Epoch 3/10 | Sample 101/391 => Loss: 3.562
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153990>
# --------------------------------------------------
# Epoch 3/10 | Sample 151/391 => Loss: 3.514
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A286D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# --------------------------------------------------
# Epoch 3/10 | Sample 201/391 => Loss: 3.438
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3590>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3390>
# --------------------------------------------------
# Epoch 3/10 | Sample 251/391 => Loss: 3.380
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153F50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153F90>
# --------------------------------------------------
# Epoch 3/10 | Sample 301/391 => Loss: 3.280
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7068450>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# --------------------------------------------------
# Epoch 3/10 | Sample 351/391 => Loss: 3.189
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9ED0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9ED0>
# --------------------------------------------------
# End of epoch 3
# Epoch 4/10 | Sample 1/391 => Loss: 2.449
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153E90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9910>
# --------------------------------------------------
# Epoch 4/10 | Sample 51/391 => Loss: 2.471
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153D90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153710>
# --------------------------------------------------
# Epoch 4/10 | Sample 101/391 => Loss: 2.514
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9050>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D95D0>
# --------------------------------------------------
# Epoch 4/10 | Sample 151/391 => Loss: 2.482
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4191810>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4191610>
# --------------------------------------------------
# Epoch 4/10 | Sample 201/391 => Loss: 2.464
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9610>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9190>
# --------------------------------------------------
# Epoch 4/10 | Sample 251/391 => Loss: 2.428
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A473FB50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41916D0>
# --------------------------------------------------
# Epoch 4/10 | Sample 301/391 => Loss: 2.406
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9510>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9D90>
# --------------------------------------------------
# Epoch 4/10 | Sample 351/391 => Loss: 2.377
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153890>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153050>
# --------------------------------------------------
# End of epoch 4
# Epoch 5/10 | Sample 1/391 => Loss: 2.173
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0AB10>
# --------------------------------------------------
# Epoch 5/10 | Sample 51/391 => Loss: 2.144
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10510>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10450>
# --------------------------------------------------
# Epoch 5/10 | Sample 101/391 => Loss: 2.138
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A28590>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10790>
# --------------------------------------------------
# Epoch 5/10 | Sample 151/391 => Loss: 2.123
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153050>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153E90>
# --------------------------------------------------
# Epoch 5/10 | Sample 201/391 => Loss: 2.110
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7068450>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10850>
# --------------------------------------------------
# Epoch 5/10 | Sample 251/391 => Loss: 2.094
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9D90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A28590>
# --------------------------------------------------
# Epoch 5/10 | Sample 301/391 => Loss: 2.080
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153510>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41531D0>
# --------------------------------------------------
# Epoch 5/10 | Sample 351/391 => Loss: 2.067
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FE9D0>
# --------------------------------------------------
# End of epoch 5
# Epoch 6/10 | Sample 1/391 => Loss: 1.916
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A250>
# --------------------------------------------------
# Epoch 6/10 | Sample 51/391 => Loss: 1.947
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F08B9F94090>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190EF50>
# --------------------------------------------------
# Epoch 6/10 | Sample 101/391 => Loss: 1.945
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A286D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190EA10>
# --------------------------------------------------
# Epoch 6/10 | Sample 151/391 => Loss: 1.934
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F08B9F94090>
# --------------------------------------------------
# Epoch 6/10 | Sample 201/391 => Loss: 1.926
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A28590>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7068450>
# --------------------------------------------------
# Epoch 6/10 | Sample 251/391 => Loss: 1.916
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9E10>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9E10>
# --------------------------------------------------
# Epoch 6/10 | Sample 301/391 => Loss: 1.905
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FE050>
# --------------------------------------------------
# Epoch 6/10 | Sample 351/391 => Loss: 1.896
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9D90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10DD0>
# --------------------------------------------------
# End of epoch 6
# Epoch 7/10 | Sample 1/391 => Loss: 1.791
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9D90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4223ED0>
# --------------------------------------------------
# Epoch 7/10 | Sample 51/391 => Loss: 1.807
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3790>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3410>
# --------------------------------------------------
# Epoch 7/10 | Sample 101/391 => Loss: 1.807
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A690>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0AA50>
# --------------------------------------------------
# Epoch 7/10 | Sample 151/391 => Loss: 1.798
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4223310>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4223CD0>
# --------------------------------------------------
# Epoch 7/10 | Sample 201/391 => Loss: 1.792
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0AFD0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A290>
# --------------------------------------------------
# Epoch 7/10 | Sample 251/391 => Loss: 1.784
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A701AFD0>
# --------------------------------------------------
# Epoch 7/10 | Sample 301/391 => Loss: 1.776
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9B10>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9C10>
# --------------------------------------------------
# Epoch 7/10 | Sample 351/391 => Loss: 1.768
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A7D0>
# --------------------------------------------------
# End of epoch 7
# Epoch 8/10 | Sample 1/391 => Loss: 1.669
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9710>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A4153D50>
# --------------------------------------------------
# Epoch 8/10 | Sample 51/391 => Loss: 1.702
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E37D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3F90>
# --------------------------------------------------
# Epoch 8/10 | Sample 101/391 => Loss: 1.698
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10B50>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A103D0>
# --------------------------------------------------
# Epoch 8/10 | Sample 151/391 => Loss: 1.692
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9450>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D97D0>
# --------------------------------------------------
# Epoch 8/10 | Sample 201/391 => Loss: 1.688
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9710>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20290>
# --------------------------------------------------
# Epoch 8/10 | Sample 251/391 => Loss: 1.680
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20850>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20CD0>
# --------------------------------------------------
# Epoch 8/10 | Sample 301/391 => Loss: 1.672
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A590>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A0A8D0>
# --------------------------------------------------
# Epoch 8/10 | Sample 351/391 => Loss: 1.666
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20490>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A205D0>
# --------------------------------------------------
# End of epoch 8
# Epoch 9/10 | Sample 1/391 => Loss: 1.597
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E36D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3790>
# --------------------------------------------------
# Epoch 9/10 | Sample 51/391 => Loss: 1.611
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9710>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7EAE4D0>
# --------------------------------------------------
# Epoch 9/10 | Sample 101/391 => Loss: 1.610
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A205D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20F90>
# --------------------------------------------------
# Epoch 9/10 | Sample 151/391 => Loss: 1.605
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190E6D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190EED0>
# --------------------------------------------------
# Epoch 9/10 | Sample 201/391 => Loss: 1.602
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190E390>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190E1D0>
# --------------------------------------------------
# Epoch 9/10 | Sample 251/391 => Loss: 1.597
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# --------------------------------------------------
# Epoch 9/10 | Sample 301/391 => Loss: 1.591
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9D90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A701AFD0>
# --------------------------------------------------
# Epoch 9/10 | Sample 351/391 => Loss: 1.586
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A49BE610>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A7E71790>
# --------------------------------------------------
# End of epoch 9
# Epoch 10/10 | Sample 1/391 => Loss: 1.520
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A286D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A10950>
# --------------------------------------------------
# Epoch 10/10 | Sample 51/391 => Loss: 1.540
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20650>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A1A20550>
# --------------------------------------------------
# Epoch 10/10 | Sample 101/391 => Loss: 1.544
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3CD0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E3310>
# --------------------------------------------------
# Epoch 10/10 | Sample 151/391 => Loss: 1.541
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E30D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A19E33D0>
# --------------------------------------------------
# Epoch 10/10 | Sample 201/391 => Loss: 1.538
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FE0D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A18FEED0>
# --------------------------------------------------
# Epoch 10/10 | Sample 251/391 => Loss: 1.533
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D9A90>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A41D90D0>
# --------------------------------------------------
# Epoch 10/10 | Sample 301/391 => Loss: 1.528
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9E10>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9E10>
# --------------------------------------------------
# Epoch 10/10 | Sample 351/391 => Loss: 1.524
# true stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A190E2D0>
# generated stroke
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F07A17F9B50>
# --------------------------------------------------
# End of epoch 10

# %%
#group print

# %%
#save

# %%
#parallel print

# %%
#history

# %%
#comment

# %%
#git

# %%
#good result

# %%
#hparams
